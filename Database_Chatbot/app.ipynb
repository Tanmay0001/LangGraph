# %%
from langchain_core.tools import tool
from dotenv import load_dotenv
import sqlite3
import requests
import os

# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated
from langchain_core.messages import BaseMessage
from langchain_groq import ChatGroq
from langgraph.checkpoint.sqlite import SqliteSaver
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode, tools_condition
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_core.tools import tool
from dotenv import load_dotenv
import sqlite3
import requests
import os

# %%
# !python -m pip install langgraph-checkpoint-sqlite
# Out:
# Collecting langgraph-checkpoint-sqlite
#   Using cached langgraph_checkpoint_sqlite-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting aiosqlite>=0.20 (from langgraph-checkpoint-sqlite)
#   Using cached aiosqlite-0.22.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langgraph-checkpoint-sqlite) (4.2.0)
# Collecting sqlite-vec>=0.1.6 (from langgraph-checkpoint-sqlite)
#   Using cached sqlite_vec-0.1.9-py3-none-win_amd64.whl.metadata (198 bytes)
# Requirement already satisfied: langchain-core>=0.2.38 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (1.6.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (1.12.2)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (0.8.3)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (0.15.0)
# Requirement already satisfied: anyio in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (4.12.1)
# Requirement already satisfied: certifi in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (1.0.9)
# Requirement already satisfied: idna in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tanmay.m4176\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.2.38->langgraph-checkpoint<5.0.0,>=4.1.0->langgraph-checkpoint-sqlite) (2.5.0)
# Using cached langgraph_checkpoint_sqlite-3.1.1-py3-none-any.whl (40 kB)
# Using cached aiosqlite-0.22.1-py3-none-any.whl (17 kB)
# Using cached sqlite_vec-0.1.9-py3-none-win_amd64.whl (292 kB)
# Installing collected packages: sqlite-vec, aiosqlite, langgraph-checkpoint-sqlite
#
#    ------------- -------------------------- 1/3 [aiosqlite]
#    ------------- -------------------------- 1/3 [aiosqlite]
#    ------------- -------------------------- 1/3 [aiosqlite]
#    -------------------------- ------------- 2/3 [langgraph-checkpoint-sqlite]
#    -------------------------- ------------- 2/3 [langgraph-checkpoint-sqlite]
#    ---------------------------------------- 3/3 [langgraph-checkpoint-sqlite]
#
# Successfully installed aiosqlite-0.22.1 langgraph-checkpoint-sqlite-3.1.1 sqlite-vec-0.1.9
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langgraph.checkpoint.sqlite import SqliteSaver
